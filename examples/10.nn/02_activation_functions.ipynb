# %% [markdown]
# ### Softmax example
# The softmax activation function, is often used in the output layer of a neural network for multi-class classification problems. It converts a vector of n real numbers into a probability distribution consisting of n probabilities.
#
# It is defined for a vector $x$ as:\
# softmax($x_i$) = $\frac{e^{x_i}}{\sum_{j}^{n} e^{x_j}}$ \
# where $x_i$ is the $i^{th}$ element of the input vector $x$.

# %%
import numpy as np

def softmax(scores):
    exp_scores = np.exp(scores)
    probabilities = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    return probabilities

# Example scores for three classes
scores = np.array([[2.0, 1.0, 0.1],
                   [1.0, 3.0, 0.2],
                   [0.1, 2.0, 3.0]])

# Applying softmax
probabilities = softmax(scores)
print("Probabilities:\n", probabilities)
# Out:
# Probabilities:
#  [[0.65900114 0.24243297 0.09856589]
#  [0.11314284 0.8360188  0.05083836]
#  [0.0386697  0.25854154 0.70278876]]

# %% [markdown]
# In this example, we have scores for three classes across three samples. We apply the softmax function to these scores. The resulting probabilities represent the likelihood of each class for each sample. Notice that the probabilities for each sample sum up to 1, ensuring that they represent valid probability distributions.

# %% [markdown]
# ### sigmoid activation function

# %%
# importing the libraries
import torch
import matplotlib.pyplot as plt

# create a PyTorch tensor
x = torch.linspace(-10, 10, 100)

# sigmoid activation function to the tensor and plot
y = torch.sigmoid(x)
plt.plot(x.numpy(), y.numpy(), color='purple')
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('Sigmoid Activation Function')
plt.show()

# %% [markdown]
# ### Hyperbolic Tangent (Tanh) activation function

# %%
# apply the tanh activation function to the tensor and plot
y = torch.tanh(x)
plt.plot(x.numpy(), y.numpy(), color='blue')
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('Tanh Activation Function')
plt.show()

# %% [markdown]
# ### Rectified Linear Unit (ReLU) activation function

# %%
# apply the ReLU activation function to the tensor and plot
y = torch.relu(x)
plt.plot(x.numpy(), y.numpy(), color='green')
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('ReLU Activation Function')
plt.show()

# %% [markdown]
# ### Leaky ReLU activation function

# %%
# apply the Leaky ReLU activation function to the tensor and plot
y = torch.nn.functional.leaky_relu(x, negative_slope=0.1)
plt.plot(x.numpy(), y.numpy(), color='green')
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('Leaky ReLU Activation Function')
plt.show()
